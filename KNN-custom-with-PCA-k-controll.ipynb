# %%
import time
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Step 1: Fetch and preprocess the MNIST dataset
print("Fetching MNIST dataset...")
X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)
samples=5000
X, y = X[:samples], y[:samples]  # Select first 10,000 images for processing
print(f"Using first {samples} images: {X.shape[0]} training samples.")

X = X / 255.0  # Normalize the pixel values to [0, 1]
y = y.astype(int)  # Convert labels to integers

# Step 2: Standardize the features
print("Standardizing features...")
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Step 3: Apply PCA for dimensionality reduction
print("Applying PCA...")
pca = PCA(n_components=0.95)  # Retain enough components to explain 95% variance
X = pca.fit_transform(X)
print(f"Reduced data shape: {X.shape}")

# Step 4: Euclidean Distance function
def euclidean_distance(x, y):
    """Calculate the Euclidean distance between two points."""
    return np.sqrt(np.sum((x - y) ** 2))

# Step 5: Implement k-NN without BallTree
def knn_predict(X_train, y_train, X_test, k=3):
    """Predict labels using k-NN and Euclidean distance."""
    y_pred = []
    
    # For each test point, calculate distances to all training points
    for test_point in X_test:
        distances = [euclidean_distance(test_point, train_point) for train_point in X_train]
        
        # Get indices of the k smallest distances
        k_indices = np.argsort(distances)[:k]
        k_nearest_labels = y_train[k_indices]
        
        # Majority vote
        predicted_label = np.bincount(k_nearest_labels).argmax()
        y_pred.append(predicted_label)
    
    return np.array(y_pred)

# Step 6: Function to perform k-NN with k control
def perform_knn_with_k_control(X, y, k_values):
    results = {}
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    
    for k in k_values:
        print(f"\nRunning k-NN with k = {k} using Euclidean distance...")
        fold_scores = []
        fold_times = []
        start_time = time.time()
        
        for fold_idx, (train_idx, test_idx) in enumerate(kf.split(X, y), 1):
            print(f"Processing fold {fold_idx} for k = {k}...")
            
            # Split the data for the current fold
            X_train, X_test = X[train_idx], X[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]

            # Predict using k-NN
            print(f"Predicting using k-NN for fold {fold_idx}...")
            y_pred = knn_predict(X_train, y_train, X_test, k=k)

            # Calculate accuracy for this fold
            accuracy = accuracy_score(y_test, y_pred)
            fold_scores.append(accuracy)

            # Track the time taken for this fold
            fold_end_time = time.time()
            fold_time = fold_end_time - start_time
            fold_times.append(fold_time)
            
            print(f"Fold {fold_idx}: Accuracy = {accuracy * 100:.2f}%, Time = {fold_time:.2f} seconds")
        
        # Compute overall results for this value of k
        mean_accuracy = np.mean(fold_scores)
        std_accuracy = np.std(fold_scores)
        total_time = np.sum(fold_times)
        best_accuracy = np.max(fold_scores)

        print(f"\nResults for k = {k}:")
        print(f"Accuracy for each fold: {[f'{score * 100:.2f}%' for score in fold_scores]}")
        print(f"Mean accuracy: {mean_accuracy * 100:.2f}%")
        print(f"Standard deviation of accuracy: {std_accuracy * 100:.2f}%")
        print(f"Best accuracy: {best_accuracy * 100:.2f}%")
        
        # Store results
        results[k] = {
            "mean_accuracy": mean_accuracy,
            "std_accuracy": std_accuracy,
            "total_time": total_time,
            "best_accuracy": best_accuracy,
        }
    
    return results

# Step 7: Run k-NN with multiple values of k
k_values = [1, 3, 5, 7]  # Example k values to test
results = perform_knn_with_k_control(X, y, k_values)

# Step 8: Summarize results
print("\nSummary of results for all k values:")
for k, result in results.items():
    print(f"k = {k}: Mean Accuracy = {result['mean_accuracy'] * 100:.2f}%, Best Accuracy = {result['best_accuracy'] * 100:.2f}%, Total Time = {result['total_time']:.2f} seconds")
# Out:
# Fetching MNIST dataset...
# Using first 5000 images: 5000 training samples.
# Standardizing features...
# Applying PCA...
# Reduced data shape: (5000, 264)
#
# Running k-NN with k = 1 using Euclidean distance...
# Processing fold 1 for k = 1...
# Predicting using k-NN for fold 1...
# Fold 1: Accuracy = 90.00%, Time = 16.71 seconds
# Processing fold 2 for k = 1...
# Predicting using k-NN for fold 2...
# Fold 2: Accuracy = 90.20%, Time = 34.61 seconds
# Processing fold 3 for k = 1...
# Predicting using k-NN for fold 3...
# Fold 3: Accuracy = 90.80%, Time = 54.24 seconds
# Processing fold 4 for k = 1...
# Predicting using k-NN for fold 4...
# Fold 4: Accuracy = 90.60%, Time = 72.06 seconds
# Processing fold 5 for k = 1...
# Predicting using k-NN for fold 5...
# Fold 5: Accuracy = 93.00%, Time = 86.66 seconds
# Processing fold 6 for k = 1...
# Predicting using k-NN for fold 6...
# Fold 6: Accuracy = 89.80%, Time = 102.47 seconds
# Processing fold 7 for k = 1...
# Predicting using k-NN for fold 7...
# Fold 7: Accuracy = 89.00%, Time = 120.41 seconds
# Processing fold 8 for k = 1...
# Predicting using k-NN for fold 8...
# Fold 8: Accuracy = 91.20%, Time = 141.92 seconds
# Processing fold 9 for k = 1...
# Predicting using k-NN for fold 9...
# Fold 9: Accuracy = 89.20%, Time = 170.73 seconds
# Processing fold 10 for k = 1...
# Predicting using k-NN for fold 10...
# Fold 10: Accuracy = 92.40%, Time = 196.78 seconds
#
# Results for k = 1:
# Accuracy for each fold: ['90.00%', '90.20%', '90.80%', '90.60%', '93.00%', '89.80%', '89.00%', '91.20%', '89.20%', '92.40%']
# Mean accuracy: 90.62%
# Standard deviation of accuracy: 1.23%
# Best accuracy: 93.00%
#
# Running k-NN with k = 3 using Euclidean distance...
# Processing fold 1 for k = 3...
# Predicting using k-NN for fold 1...
# Fold 1: Accuracy = 90.00%, Time = 28.42 seconds
# Processing fold 2 for k = 3...
# Predicting using k-NN for fold 2...
# Fold 2: Accuracy = 89.80%, Time = 59.41 seconds
# Processing fold 3 for k = 3...
# Predicting using k-NN for fold 3...
# Fold 3: Accuracy = 92.20%, Time = 95.10 seconds
# Processing fold 4 for k = 3...
# Predicting using k-NN for fold 4...
# Fold 4: Accuracy = 90.00%, Time = 128.33 seconds
# Processing fold 5 for k = 3...
# Predicting using k-NN for fold 5...
# Fold 5: Accuracy = 91.00%, Time = 163.88 seconds
# Processing fold 6 for k = 3...
# Predicting using k-NN for fold 6...
# Fold 6: Accuracy = 88.40%, Time = 195.55 seconds
# Processing fold 7 for k = 3...
# Predicting using k-NN for fold 7...
# Fold 7: Accuracy = 89.00%, Time = 225.34 seconds
# Processing fold 8 for k = 3...
# Predicting using k-NN for fold 8...
# Fold 8: Accuracy = 91.80%, Time = 254.83 seconds
# Processing fold 9 for k = 3...
# Predicting using k-NN for fold 9...
# Fold 9: Accuracy = 89.00%, Time = 289.71 seconds
# Processing fold 10 for k = 3...
# Predicting using k-NN for fold 10...
# Fold 10: Accuracy = 92.40%, Time = 322.98 seconds
#
# Results for k = 3:
# Accuracy for each fold: ['90.00%', '89.80%', '92.20%', '90.00%', '91.00%', '88.40%', '89.00%', '91.80%', '89.00%', '92.40%']
# Mean accuracy: 90.36%
# Standard deviation of accuracy: 1.35%
# Best accuracy: 92.40%
#
# Running k-NN with k = 5 using Euclidean distance...
# Processing fold 1 for k = 5...
# Predicting using k-NN for fold 1...
# Fold 1: Accuracy = 89.20%, Time = 29.03 seconds
# Processing fold 2 for k = 5...
# Predicting using k-NN for fold 2...
# Fold 2: Accuracy = 90.40%, Time = 58.52 seconds
# Processing fold 3 for k = 5...
# Predicting using k-NN for fold 3...
# Fold 3: Accuracy = 90.80%, Time = 87.73 seconds
# Processing fold 4 for k = 5...
# Predicting using k-NN for fold 4...
# Fold 4: Accuracy = 90.40%, Time = 120.57 seconds
# Processing fold 5 for k = 5...
# Predicting using k-NN for fold 5...
# Fold 5: Accuracy = 90.80%, Time = 151.89 seconds
# Processing fold 6 for k = 5...
# Predicting using k-NN for fold 6...
# Fold 6: Accuracy = 89.40%, Time = 187.17 seconds
# Processing fold 7 for k = 5...
# Predicting using k-NN for fold 7...
# Fold 7: Accuracy = 88.80%, Time = 221.27 seconds
# Processing fold 8 for k = 5...
# Predicting using k-NN for fold 8...
# Fold 8: Accuracy = 92.00%, Time = 253.67 seconds
# Processing fold 9 for k = 5...
# Predicting using k-NN for fold 9...
# Fold 9: Accuracy = 90.60%, Time = 286.92 seconds
# Processing fold 10 for k = 5...
# Predicting using k-NN for fold 10...
# Fold 10: Accuracy = 91.80%, Time = 321.51 seconds
#
# Results for k = 5:
# Accuracy for each fold: ['89.20%', '90.40%', '90.80%', '90.40%', '90.80%', '89.40%', '88.80%', '92.00%', '90.60%', '91.80%']
# Mean accuracy: 90.42%
# Standard deviation of accuracy: 0.99%
# Best accuracy: 92.00%
#
# Running k-NN with k = 7 using Euclidean distance...
# Processing fold 1 for k = 7...
# Predicting using k-NN for fold 1...
# Fold 1: Accuracy = 88.60%, Time = 30.19 seconds
# Processing fold 2 for k = 7...
# Predicting using k-NN for fold 2...
# Fold 2: Accuracy = 89.20%, Time = 61.42 seconds
# Processing fold 3 for k = 7...
# Predicting using k-NN for fold 3...
# Fold 3: Accuracy = 91.00%, Time = 93.99 seconds
# Processing fold 4 for k = 7...
# Predicting using k-NN for fold 4...
# Fold 4: Accuracy = 89.60%, Time = 128.64 seconds
# Processing fold 5 for k = 7...
# Predicting using k-NN for fold 5...
# Fold 5: Accuracy = 90.80%, Time = 164.77 seconds
# Processing fold 6 for k = 7...
# Predicting using k-NN for fold 6...
# Fold 6: Accuracy = 88.40%, Time = 197.83 seconds
# Processing fold 7 for k = 7...
# Predicting using k-NN for fold 7...
# Fold 7: Accuracy = 89.20%, Time = 229.88 seconds
# Processing fold 8 for k = 7...
# Predicting using k-NN for fold 8...
# Fold 8: Accuracy = 92.40%, Time = 262.84 seconds
# Processing fold 9 for k = 7...
# Predicting using k-NN for fold 9...
# Fold 9: Accuracy = 90.00%, Time = 294.38 seconds
# Processing fold 10 for k = 7...
# Predicting using k-NN for fold 10...
# Fold 10: Accuracy = 91.20%, Time = 324.89 seconds
#
# Results for k = 7:
# Accuracy for each fold: ['88.60%', '89.20%', '91.00%', '89.60%', '90.80%', '88.40%', '89.20%', '92.40%', '90.00%', '91.20%']
# Mean accuracy: 90.04%
# Standard deviation of accuracy: 1.22%
# Best accuracy: 92.40%
#
# Summary of results for all k values:
# k = 1: Mean Accuracy = 90.62%, Best Accuracy = 93.00%, Total Time = 996.58 seconds
# k = 3: Mean Accuracy = 90.36%, Best Accuracy = 92.40%, Total Time = 1763.53 seconds
# k = 5: Mean Accuracy = 90.42%, Best Accuracy = 92.00%, Total Time = 1718.28 seconds
# k = 7: Mean Accuracy = 90.04%, Best Accuracy = 92.40%, Total Time = 1788.83 seconds

# %%
import time
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Step 1: Fetch and preprocess the MNIST dataset
print("Fetching MNIST dataset...")
X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)
samples=5000
X, y = X[:samples], y[:samples]  # Select first 10,000 images for processing
print(f"Using first {samples} images: {X.shape[0]} training samples.")

X = X / 255.0  # Normalize the pixel values to [0, 1]
y = y.astype(int)  # Convert labels to integers

# Step 2: Standardize the features
print("Standardizing features...")
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Step 3: Apply PCA for dimensionality reduction
print("Applying PCA...")
pca = PCA(n_components=0.95)  # Retain enough components to explain 95% variance
X = pca.fit_transform(X)
print(f"Reduced data shape: {X.shape}")

# Step 4: Define the custom cosine distance function
def cosine_similarity(point1, point2):
    """Calculate the cosine similarity between two points."""
    dot_product = np.dot(point1, point2)
    norm1 = np.linalg.norm(point1)
    norm2 = np.linalg.norm(point2)
    return dot_product / (norm1 * norm2)

def cosine_distance(x, y):
    """Calculate the cosine distance between two vectors."""
    return 1 - cosine_similarity(x, y)

# Step 5: Function to perform k-NN without BallTree and with custom cosine distance
def perform_knn(X, y, k_values):
    results = {}
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    
    for k in k_values:
        print(f"\nRunning k-NN with k = {k} using cosine distance...")
        fold_scores = []
        fold_times = []
        start_time = time.time()
        
        for fold_idx, (train_idx, test_idx) in enumerate(kf.split(X, y), 1):
            print(f"Processing fold {fold_idx} for k = {k}...")
            
            # Split the data for the current fold
            X_train, X_test = X[train_idx], X[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]

            # Predict using k-NN with custom cosine distance
            def knn_predict(X_train, y_train, X_test, k):
                y_pred = []
                for test_point in X_test:
                    # Calculate distances to all training points
                    distances = [cosine_distance(test_point, train_point) for train_point in X_train]
                    
                    # Get indices of the k smallest distances
                    k_indices = np.argsort(distances)[:k]
                    k_nearest_labels = y_train[k_indices]
                    
                    # Majority vote
                    predicted_label = np.bincount(k_nearest_labels).argmax()
                    y_pred.append(predicted_label)
                return np.array(y_pred)

            # Make predictions using k-NN
            y_pred = knn_predict(X_train, y_train, X_test, k)

            # Calculate accuracy for this fold
            accuracy = accuracy_score(y_test, y_pred)
            fold_scores.append(accuracy)

            # Track the time taken for this fold
            fold_end_time = time.time()
            fold_time = fold_end_time - start_time
            fold_times.append(fold_time)
            
            print(f"Fold {fold_idx}: Accuracy = {accuracy * 100:.2f}%, Time = {fold_time:.2f} seconds")
        
        # Compute overall results for this value of k
        mean_accuracy = np.mean(fold_scores)
        std_accuracy = np.std(fold_scores)
        total_time = np.sum(fold_times)
        best_accuracy = np.max(fold_scores)

        print(f"\nResults for k = {k}:")
        print(f"Accuracy for each fold: {[f'{score * 100:.2f}%' for score in fold_scores]}")
        print(f"Mean accuracy: {mean_accuracy * 100:.2f}%")
        print(f"Standard deviation of accuracy: {std_accuracy * 100:.2f}%")
        print(f"Best accuracy: {best_accuracy * 100:.2f}%")
        
        # Store results
        results[k] = {
            "mean_accuracy": mean_accuracy,
            "std_accuracy": std_accuracy,
            "total_time": total_time,
            "best_accuracy": best_accuracy,
        }
    
    return results

# Step 6: Run k-NN with multiple values of k
k_values = [1, 3, 5, 7]  # Example k values to test
results = perform_knn(X, y, k_values)

# Step 7: Summarize results
print("\nSummary of results for all k values:")
for k, result in results.items():
    print(f"k = {k}: Mean Accuracy = {result['mean_accuracy'] * 100:.2f}%, Best Accuracy = {result['best_accuracy'] * 100:.2f}%, Total Time = {result['total_time']:.2f} seconds")
# Out:
# Fetching MNIST dataset...
# Using first 5000 images: 5000 training samples.
# Standardizing features...
# Applying PCA...
# Reduced data shape: (5000, 264)
#
# Running k-NN with k = 1 using cosine distance...
# Processing fold 1 for k = 1...
# Fold 1: Accuracy = 89.60%, Time = 44.48 seconds
# Processing fold 2 for k = 1...
# Fold 2: Accuracy = 90.60%, Time = 91.38 seconds
# Processing fold 3 for k = 1...
# Fold 3: Accuracy = 91.20%, Time = 133.07 seconds
# Processing fold 4 for k = 1...
# Fold 4: Accuracy = 90.20%, Time = 179.71 seconds
# Processing fold 5 for k = 1...
# Fold 5: Accuracy = 92.60%, Time = 221.75 seconds
# Processing fold 6 for k = 1...
# Fold 6: Accuracy = 90.20%, Time = 262.18 seconds
# Processing fold 7 for k = 1...
# Fold 7: Accuracy = 88.80%, Time = 305.56 seconds
# Processing fold 8 for k = 1...
# Fold 8: Accuracy = 91.40%, Time = 349.88 seconds
# Processing fold 9 for k = 1...
# Fold 9: Accuracy = 89.20%, Time = 397.88 seconds
# Processing fold 10 for k = 1...
# Fold 10: Accuracy = 93.20%, Time = 442.07 seconds
#
# Results for k = 1:
# Accuracy for each fold: ['89.60%', '90.60%', '91.20%', '90.20%', '92.60%', '90.20%', '88.80%', '91.40%', '89.20%', '93.20%']
# Mean accuracy: 90.70%
# Standard deviation of accuracy: 1.35%
# Best accuracy: 93.20%
#
# Running k-NN with k = 3 using cosine distance...
# Processing fold 1 for k = 3...
# Fold 1: Accuracy = 89.20%, Time = 43.89 seconds
# Processing fold 2 for k = 3...
# Fold 2: Accuracy = 91.00%, Time = 83.41 seconds
# Processing fold 3 for k = 3...
# Fold 3: Accuracy = 91.40%, Time = 123.10 seconds
# Processing fold 4 for k = 3...
# Fold 4: Accuracy = 89.40%, Time = 164.66 seconds
# Processing fold 5 for k = 3...
# Fold 5: Accuracy = 92.20%, Time = 206.17 seconds
# Processing fold 6 for k = 3...
# Fold 6: Accuracy = 89.80%, Time = 251.79 seconds
# Processing fold 7 for k = 3...
# Fold 7: Accuracy = 88.00%, Time = 298.02 seconds
# Processing fold 8 for k = 3...
# Fold 8: Accuracy = 89.80%, Time = 333.21 seconds
# Processing fold 9 for k = 3...
# Fold 9: Accuracy = 90.80%, Time = 378.76 seconds
# Processing fold 10 for k = 3...
# Fold 10: Accuracy = 90.80%, Time = 410.81 seconds
#
# Results for k = 3:
# Accuracy for each fold: ['89.20%', '91.00%', '91.40%', '89.40%', '92.20%', '89.80%', '88.00%', '89.80%', '90.80%', '90.80%']
# Mean accuracy: 90.24%
# Standard deviation of accuracy: 1.17%
# Best accuracy: 92.20%
#
# Running k-NN with k = 5 using cosine distance...
# Processing fold 1 for k = 5...
# Fold 1: Accuracy = 90.40%, Time = 43.32 seconds
# Processing fold 2 for k = 5...
# Fold 2: Accuracy = 91.00%, Time = 80.92 seconds
# Processing fold 3 for k = 5...
# Fold 3: Accuracy = 91.40%, Time = 127.45 seconds
# Processing fold 4 for k = 5...
# Fold 4: Accuracy = 89.60%, Time = 176.51 seconds
# Processing fold 5 for k = 5...
# Fold 5: Accuracy = 91.20%, Time = 220.18 seconds
# Processing fold 6 for k = 5...
# Fold 6: Accuracy = 89.60%, Time = 257.10 seconds
# Processing fold 7 for k = 5...
# Fold 7: Accuracy = 87.40%, Time = 301.26 seconds
# Processing fold 8 for k = 5...
# Fold 8: Accuracy = 91.40%, Time = 332.09 seconds
# Processing fold 9 for k = 5...
# Fold 9: Accuracy = 89.60%, Time = 372.52 seconds
# Processing fold 10 for k = 5...
# Fold 10: Accuracy = 91.40%, Time = 414.01 seconds
#
# Results for k = 5:
# Accuracy for each fold: ['90.40%', '91.00%', '91.40%', '89.60%', '91.20%', '89.60%', '87.40%', '91.40%', '89.60%', '91.40%']
# Mean accuracy: 90.30%
# Standard deviation of accuracy: 1.22%
# Best accuracy: 91.40%
#
# Running k-NN with k = 7 using cosine distance...
# Processing fold 1 for k = 7...
# Fold 1: Accuracy = 89.40%, Time = 46.25 seconds
# Processing fold 2 for k = 7...
# Fold 2: Accuracy = 90.80%, Time = 84.21 seconds
# Processing fold 3 for k = 7...
# Fold 3: Accuracy = 91.00%, Time = 129.23 seconds
# Processing fold 4 for k = 7...
# Fold 4: Accuracy = 88.80%, Time = 174.15 seconds
# Processing fold 5 for k = 7...
# Fold 5: Accuracy = 91.40%, Time = 218.35 seconds
# Processing fold 6 for k = 7...
# Fold 6: Accuracy = 89.60%, Time = 245.50 seconds
# Processing fold 7 for k = 7...
# Fold 7: Accuracy = 88.60%, Time = 269.44 seconds
# Processing fold 8 for k = 7...
# Fold 8: Accuracy = 91.80%, Time = 292.93 seconds
# Processing fold 9 for k = 7...
# Fold 9: Accuracy = 89.80%, Time = 317.46 seconds
# Processing fold 10 for k = 7...
# Fold 10: Accuracy = 91.60%, Time = 340.00 seconds
#
# Results for k = 7:
# Accuracy for each fold: ['89.40%', '90.80%', '91.00%', '88.80%', '91.40%', '89.60%', '88.60%', '91.80%', '89.80%', '91.60%']
# Mean accuracy: 90.28%
# Standard deviation of accuracy: 1.12%
# Best accuracy: 91.80%
#
# Summary of results for all k values:
# k = 1: Mean Accuracy = 90.70%, Best Accuracy = 93.20%, Total Time = 2427.95 seconds
# k = 3: Mean Accuracy = 90.24%, Best Accuracy = 92.20%, Total Time = 2293.83 seconds
# k = 5: Mean Accuracy = 90.30%, Best Accuracy = 91.40%, Total Time = 2325.38 seconds
# k = 7: Mean Accuracy = 90.28%, Best Accuracy = 91.80%, Total Time = 2117.51 seconds

# %%
import time
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Step 1: Fetch and preprocess the MNIST dataset
print("Fetching MNIST dataset...")
X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)
samples=5000
X, y = X[:samples], y[:samples]  # Select first 10,000 images for processing
print(f"Using first {samples} images: {X.shape[0]} training samples.")

X = X / 255.0  # Normalize the pixel values to [0, 1]
y = y.astype(int)  # Convert labels to integers

# Step 2: Standardize the features
print("Standardizing features...")
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Step 3: Apply PCA for dimensionality reduction
print("Applying PCA...")
pca = PCA(n_components=0.95)  # Retain enough components to explain 95% variance
X = pca.fit_transform(X)
print(f"Reduced data shape: {X.shape}")

# Step 4: Define the Manhattan distance function
def manhattan_distance(x, y):
    """Calculate the Manhattan (L1) distance between two points."""
    return np.sum(np.abs(x - y))

# Step 5: Function to perform k-NN without BallTree and with custom Manhattan distance
def perform_knn(X, y, k_values):
    results = {}
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    
    for k in k_values:
        print(f"\nRunning k-NN with k = {k} using Manhattan distance...")
        fold_scores = []
        fold_times = []
        start_time = time.time()
        
        for fold_idx, (train_idx, test_idx) in enumerate(kf.split(X, y), 1):
            print(f"Processing fold {fold_idx} for k = {k}...")
            
            # Split the data for the current fold
            X_train, X_test = X[train_idx], X[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]

            # Predict using k-NN with custom Manhattan distance
            def knn_predict(X_train, y_train, X_test, k):
                y_pred = []
                for test_point in X_test:
                    # Calculate distances to all training points
                    distances = [manhattan_distance(test_point, train_point) for train_point in X_train]
                    
                    # Get indices of the k smallest distances
                    k_indices = np.argsort(distances)[:k]
                    k_nearest_labels = y_train[k_indices]
                    
                    # Majority vote
                    predicted_label = np.bincount(k_nearest_labels).argmax()
                    y_pred.append(predicted_label)
                return np.array(y_pred)

            # Make predictions using k-NN
            y_pred = knn_predict(X_train, y_train, X_test, k)

            # Calculate accuracy for this fold
            accuracy = accuracy_score(y_test, y_pred)
            fold_scores.append(accuracy)

            # Track the time taken for this fold
            fold_end_time = time.time()
            fold_time = fold_end_time - start_time
            fold_times.append(fold_time)
            
            print(f"Fold {fold_idx}: Accuracy = {accuracy * 100:.2f}%, Time = {fold_time:.2f} seconds")
        
        # Compute overall results for this value of k
        mean_accuracy = np.mean(fold_scores)
        std_accuracy = np.std(fold_scores)
        total_time = np.sum(fold_times)
        best_accuracy = np.max(fold_scores)

        print(f"\nResults for k = {k}:")
        print(f"Accuracy for each fold: {[f'{score * 100:.2f}%' for score in fold_scores]}")
        print(f"Mean accuracy: {mean_accuracy * 100:.2f}%")
        print(f"Standard deviation of accuracy: {std_accuracy * 100:.2f}%")
        print(f"Best accuracy: {best_accuracy * 100:.2f}%")
        
        # Store results
        results[k] = {
            "mean_accuracy": mean_accuracy,
            "std_accuracy": std_accuracy,
            "total_time": total_time,
            "best_accuracy": best_accuracy,
        }
    
    return results

# Step 6: Run k-NN with multiple values of k
k_values = [1, 3, 5, 7]  # Example k values to test
results = perform_knn(X, y, k_values)

# Step 7: Summarize results
print("\nSummary of results for all k values:")
for k, result in results.items():
    print(f"k = {k}: Mean Accuracy = {result['mean_accuracy'] * 100:.2f}%, Best Accuracy = {result['best_accuracy'] * 100:.2f}%, Total Time = {result['total_time']:.2f} seconds")
# Out:
# Fetching MNIST dataset...
# Using first 5000 images: 5000 training samples.
# Standardizing features...
# Applying PCA...
# Reduced data shape: (5000, 264)
#
# Running k-NN with k = 1 using Manhattan distance...
# Processing fold 1 for k = 1...
# Fold 1: Accuracy = 88.00%, Time = 16.09 seconds
# Processing fold 2 for k = 1...
# Fold 2: Accuracy = 88.40%, Time = 31.83 seconds
# Processing fold 3 for k = 1...
# Fold 3: Accuracy = 89.80%, Time = 47.89 seconds
# Processing fold 4 for k = 1...
# Fold 4: Accuracy = 88.40%, Time = 63.57 seconds
# Processing fold 5 for k = 1...
# Fold 5: Accuracy = 89.40%, Time = 79.23 seconds
# Processing fold 6 for k = 1...
# Fold 6: Accuracy = 87.00%, Time = 95.72 seconds
# Processing fold 7 for k = 1...
# Fold 7: Accuracy = 86.60%, Time = 111.79 seconds
# Processing fold 8 for k = 1...
# Fold 8: Accuracy = 88.80%, Time = 129.54 seconds
# Processing fold 9 for k = 1...
# Fold 9: Accuracy = 87.00%, Time = 145.87 seconds
# Processing fold 10 for k = 1...
# Fold 10: Accuracy = 89.80%, Time = 162.50 seconds
#
# Results for k = 1:
# Accuracy for each fold: ['88.00%', '88.40%', '89.80%', '88.40%', '89.40%', '87.00%', '86.60%', '88.80%', '87.00%', '89.80%']
# Mean accuracy: 88.32%
# Standard deviation of accuracy: 1.11%
# Best accuracy: 89.80%
#
# Running k-NN with k = 3 using Manhattan distance...
# Processing fold 1 for k = 3...
# Fold 1: Accuracy = 87.20%, Time = 16.17 seconds
# Processing fold 2 for k = 3...
# Fold 2: Accuracy = 87.80%, Time = 32.08 seconds
# Processing fold 3 for k = 3...
# Fold 3: Accuracy = 88.40%, Time = 47.77 seconds
# Processing fold 4 for k = 3...
# Fold 4: Accuracy = 85.80%, Time = 63.66 seconds
# Processing fold 5 for k = 3...
# Fold 5: Accuracy = 88.40%, Time = 80.31 seconds
# Processing fold 6 for k = 3...
# Fold 6: Accuracy = 86.60%, Time = 96.46 seconds
# Processing fold 7 for k = 3...
# Fold 7: Accuracy = 86.40%, Time = 112.29 seconds
# Processing fold 8 for k = 3...
# Fold 8: Accuracy = 88.00%, Time = 129.00 seconds
# Processing fold 9 for k = 3...
# Fold 9: Accuracy = 87.60%, Time = 145.82 seconds
# Processing fold 10 for k = 3...
# Fold 10: Accuracy = 89.80%, Time = 162.43 seconds
#
# Results for k = 3:
# Accuracy for each fold: ['87.20%', '87.80%', '88.40%', '85.80%', '88.40%', '86.60%', '86.40%', '88.00%', '87.60%', '89.80%']
# Mean accuracy: 87.60%
# Standard deviation of accuracy: 1.10%
# Best accuracy: 89.80%
#
# Running k-NN with k = 5 using Manhattan distance...
# Processing fold 1 for k = 5...
# Fold 1: Accuracy = 87.20%, Time = 16.45 seconds
# Processing fold 2 for k = 5...
# Fold 2: Accuracy = 87.40%, Time = 33.16 seconds
# Processing fold 3 for k = 5...
# Fold 3: Accuracy = 89.00%, Time = 50.77 seconds
# Processing fold 4 for k = 5...
# Fold 4: Accuracy = 85.80%, Time = 67.63 seconds
# Processing fold 5 for k = 5...
# Fold 5: Accuracy = 88.00%, Time = 84.27 seconds
# Processing fold 6 for k = 5...
# Fold 6: Accuracy = 86.60%, Time = 101.22 seconds
# Processing fold 7 for k = 5...
# Fold 7: Accuracy = 86.40%, Time = 118.00 seconds
# Processing fold 8 for k = 5...
# Fold 8: Accuracy = 88.60%, Time = 134.47 seconds
# Processing fold 9 for k = 5...
# Fold 9: Accuracy = 88.60%, Time = 151.33 seconds
# Processing fold 10 for k = 5...
# Fold 10: Accuracy = 89.40%, Time = 168.49 seconds
#
# Results for k = 5:
# Accuracy for each fold: ['87.20%', '87.40%', '89.00%', '85.80%', '88.00%', '86.60%', '86.40%', '88.60%', '88.60%', '89.40%']
# Mean accuracy: 87.70%
# Standard deviation of accuracy: 1.15%
# Best accuracy: 89.40%
#
# Running k-NN with k = 7 using Manhattan distance...
# Processing fold 1 for k = 7...
# Fold 1: Accuracy = 86.40%, Time = 16.61 seconds
# Processing fold 2 for k = 7...
# Fold 2: Accuracy = 86.60%, Time = 33.40 seconds
# Processing fold 3 for k = 7...
# Fold 3: Accuracy = 87.80%, Time = 50.72 seconds
# Processing fold 4 for k = 7...
# Fold 4: Accuracy = 85.40%, Time = 67.56 seconds
# Processing fold 5 for k = 7...
# Fold 5: Accuracy = 87.20%, Time = 84.17 seconds
# Processing fold 6 for k = 7...
# Fold 6: Accuracy = 85.60%, Time = 100.97 seconds
# Processing fold 7 for k = 7...
# Fold 7: Accuracy = 85.20%, Time = 118.11 seconds
# Processing fold 8 for k = 7...
# Fold 8: Accuracy = 89.00%, Time = 134.61 seconds
# Processing fold 9 for k = 7...
# Fold 9: Accuracy = 87.60%, Time = 150.78 seconds
# Processing fold 10 for k = 7...
# Fold 10: Accuracy = 90.20%, Time = 166.79 seconds
#
# Results for k = 7:
# Accuracy for each fold: ['86.40%', '86.60%', '87.80%', '85.40%', '87.20%', '85.60%', '85.20%', '89.00%', '87.60%', '90.20%']
# Mean accuracy: 87.10%
# Standard deviation of accuracy: 1.53%
# Best accuracy: 90.20%
#
# Summary of results for all k values:
# k = 1: Mean Accuracy = 88.32%, Best Accuracy = 89.80%, Total Time = 884.04 seconds
# k = 3: Mean Accuracy = 87.60%, Best Accuracy = 89.80%, Total Time = 885.99 seconds
# k = 5: Mean Accuracy = 87.70%, Best Accuracy = 89.40%, Total Time = 925.79 seconds
# k = 7: Mean Accuracy = 87.10%, Best Accuracy = 90.20%, Total Time = 923.72 seconds
