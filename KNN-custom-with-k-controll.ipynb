# %%
import time
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# Step 1: Fetch and preprocess the MNIST dataset
print("Fetching MNIST dataset...")
X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)
samples=5000
X, y = X[:samples], y[:samples]  # Select first 10,000 images for processing
print(f"Using first {samples} images: {X.shape[0]} training samples.")

X = X / 255.0  # Normalize the pixel values to [0, 1]
y = y.astype(int)  # Convert labels to integers

# Step 2: Standardize the features
print("Standardizing features...")
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Step 3: Euclidean Distance function
def euclidean_distance(x, y):
    """Calculate the Euclidean distance between two points."""
    return np.sqrt(np.sum((x - y) ** 2))

# Step 4: Implement k-NN without BallTree
def knn_predict(X_train, y_train, X_test, k=3):
    """Predict labels using k-NN and Euclidean distance."""
    y_pred = []
    
    # For each test point, calculate distances to all training points
    for test_point in X_test:
        distances = [euclidean_distance(test_point, train_point) for train_point in X_train]
        
        # Get indices of the k smallest distances
        k_indices = np.argsort(distances)[:k]
        k_nearest_labels = y_train[k_indices]
        
        # Majority vote
        predicted_label = np.bincount(k_nearest_labels).argmax()
        y_pred.append(predicted_label)
    
    return np.array(y_pred)

# Step 5: Function to perform k-NN with k control
def perform_knn_with_k_control(X, y, k_values):
    results = {}
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    
    for k in k_values:
        print(f"\nRunning k-NN with k = {k}...")
        fold_scores = []
        fold_times = []
        start_time = time.time()
        
        for fold_idx, (train_idx, test_idx) in enumerate(kf.split(X, y), 1):
            print(f"Processing fold {fold_idx} for k = {k}...")
            
            # Split the data for the current fold
            X_train, X_test = X[train_idx], X[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]

            # Predict using k-NN for the current value of k
            y_pred = knn_predict(X_train, y_train, X_test, k=k)

            # Calculate accuracy for this fold
            accuracy = accuracy_score(y_test, y_pred)
            fold_scores.append(accuracy)

            # Track the time taken for this fold
            fold_end_time = time.time()
            fold_time = fold_end_time - start_time
            fold_times.append(fold_time)
            
            print(f"Fold {fold_idx}: Accuracy = {accuracy * 100:.2f}%, Time = {fold_time:.2f} seconds")
        
        # Compute overall results for this value of k
        mean_accuracy = np.mean(fold_scores)
        std_accuracy = np.std(fold_scores)
        total_time = np.sum(fold_times)
        best_accuracy = np.max(fold_scores)

        print(f"\nResults for k = {k}:")
        print(f"Accuracy for each fold: {[f'{score * 100:.2f}%' for score in fold_scores]}")
        print(f"Mean accuracy: {mean_accuracy * 100:.2f}%")
        print(f"Standard deviation of accuracy: {std_accuracy * 100:.2f}%")
        print(f"Best accuracy: {best_accuracy * 100:.2f}%")
        
        # Store results
        results[k] = {
            "mean_accuracy": mean_accuracy,
            "std_accuracy": std_accuracy,
            "total_time": total_time,
            "best_accuracy": best_accuracy,
        }
    
    return results

# Step 6: Run k-NN with multiple values of k
k_values = [1,3,5,7]  # Example k values to test
results = perform_knn_with_k_control(X, y, k_values)

# Step 7: Summarize results
print("\nSummary of results for all k values:")
for k, result in results.items():
    print(f"k = {k}: Mean Accuracy = {result['mean_accuracy'] * 100:.2f}%, Best Accuracy = {result['best_accuracy'] * 100:.2f}%, Total Time = {result['total_time']:.2f} seconds")
# Out:
# Fetching MNIST dataset...
# Using first 10,000 images: 5000 training samples.
# Standardizing features...
#
# Running k-NN with k = 1...
# Processing fold 1 for k = 1...
# Fold 1: Accuracy = 89.00%, Time = 13.39 seconds
# Processing fold 2 for k = 1...
# Fold 2: Accuracy = 89.60%, Time = 27.19 seconds
# Processing fold 3 for k = 1...
# Fold 3: Accuracy = 91.00%, Time = 41.48 seconds
# Processing fold 4 for k = 1...
# Fold 4: Accuracy = 90.20%, Time = 55.99 seconds
# Processing fold 5 for k = 1...
# Fold 5: Accuracy = 91.40%, Time = 70.63 seconds
# Processing fold 6 for k = 1...
# Fold 6: Accuracy = 88.40%, Time = 84.98 seconds
# Processing fold 7 for k = 1...
# Fold 7: Accuracy = 88.20%, Time = 99.34 seconds
# Processing fold 8 for k = 1...
# Fold 8: Accuracy = 91.20%, Time = 113.12 seconds
# Processing fold 9 for k = 1...
# Fold 9: Accuracy = 88.40%, Time = 127.50 seconds
# Processing fold 10 for k = 1...
# Fold 10: Accuracy = 91.80%, Time = 141.90 seconds
#
# Results for k = 1:
# Accuracy for each fold: ['89.00%', '89.60%', '91.00%', '90.20%', '91.40%', '88.40%', '88.20%', '91.20%', '88.40%', '91.80%']
# Mean accuracy: 89.92%
# Standard deviation of accuracy: 1.31%
# Best accuracy: 91.80%
#
# Running k-NN with k = 3...
# Processing fold 1 for k = 3...
# Fold 1: Accuracy = 89.60%, Time = 14.85 seconds
# Processing fold 2 for k = 3...
# Fold 2: Accuracy = 89.20%, Time = 28.96 seconds
# Processing fold 3 for k = 3...
# Fold 3: Accuracy = 91.20%, Time = 43.62 seconds
# Processing fold 4 for k = 3...
# Fold 4: Accuracy = 88.80%, Time = 57.38 seconds
# Processing fold 5 for k = 3...
# Fold 5: Accuracy = 90.40%, Time = 71.05 seconds
# Processing fold 6 for k = 3...
# Fold 6: Accuracy = 88.20%, Time = 85.14 seconds
# Processing fold 7 for k = 3...
# Fold 7: Accuracy = 88.80%, Time = 98.57 seconds
# Processing fold 8 for k = 3...
# Fold 8: Accuracy = 91.60%, Time = 112.14 seconds
# Processing fold 9 for k = 3...
# Fold 9: Accuracy = 88.80%, Time = 125.80 seconds
# Processing fold 10 for k = 3...
# Fold 10: Accuracy = 93.00%, Time = 139.53 seconds
#
# Results for k = 3:
# Accuracy for each fold: ['89.60%', '89.20%', '91.20%', '88.80%', '90.40%', '88.20%', '88.80%', '91.60%', '88.80%', '93.00%']
# Mean accuracy: 89.96%
# Standard deviation of accuracy: 1.47%
# Best accuracy: 93.00%
#
# Running k-NN with k = 5...
# Processing fold 1 for k = 5...
# Fold 1: Accuracy = 88.60%, Time = 13.71 seconds
# Processing fold 2 for k = 5...
# Fold 2: Accuracy = 90.20%, Time = 27.31 seconds
# Processing fold 3 for k = 5...
# Fold 3: Accuracy = 90.60%, Time = 40.91 seconds
# Processing fold 4 for k = 5...
# Fold 4: Accuracy = 89.60%, Time = 54.17 seconds
# Processing fold 5 for k = 5...
# Fold 5: Accuracy = 89.60%, Time = 67.78 seconds
# Processing fold 6 for k = 5...
# Fold 6: Accuracy = 88.00%, Time = 81.34 seconds
# Processing fold 7 for k = 5...
# Fold 7: Accuracy = 89.20%, Time = 95.09 seconds
# Processing fold 8 for k = 5...
# Fold 8: Accuracy = 91.80%, Time = 109.88 seconds
# Processing fold 9 for k = 5...
# Fold 9: Accuracy = 89.60%, Time = 123.38 seconds
# Processing fold 10 for k = 5...
# Fold 10: Accuracy = 91.60%, Time = 136.79 seconds
#
# Results for k = 5:
# Accuracy for each fold: ['88.60%', '90.20%', '90.60%', '89.60%', '89.60%', '88.00%', '89.20%', '91.80%', '89.60%', '91.60%']
# Mean accuracy: 89.88%
# Standard deviation of accuracy: 1.15%
# Best accuracy: 91.80%
#
# Running k-NN with k = 7...
# Processing fold 1 for k = 7...
# Fold 1: Accuracy = 88.40%, Time = 13.14 seconds
# Processing fold 2 for k = 7...
# Fold 2: Accuracy = 88.60%, Time = 26.57 seconds
# Processing fold 3 for k = 7...
# Fold 3: Accuracy = 91.00%, Time = 40.23 seconds
# Processing fold 4 for k = 7...
# Fold 4: Accuracy = 88.00%, Time = 53.43 seconds
# Processing fold 5 for k = 7...
# Fold 5: Accuracy = 89.40%, Time = 66.57 seconds
# Processing fold 6 for k = 7...
# Fold 6: Accuracy = 87.80%, Time = 79.82 seconds
# Processing fold 7 for k = 7...
# Fold 7: Accuracy = 88.80%, Time = 93.05 seconds
# Processing fold 8 for k = 7...
# Fold 8: Accuracy = 91.60%, Time = 106.45 seconds
# Processing fold 9 for k = 7...
# Fold 9: Accuracy = 89.60%, Time = 120.63 seconds
# Processing fold 10 for k = 7...
# Fold 10: Accuracy = 90.80%, Time = 134.75 seconds
#
# Results for k = 7:
# Accuracy for each fold: ['88.40%', '88.60%', '91.00%', '88.00%', '89.40%', '87.80%', '88.80%', '91.60%', '89.60%', '90.80%']
# Mean accuracy: 89.40%
# Standard deviation of accuracy: 1.26%
# Best accuracy: 91.60%
#
# Summary of results for all k values:
# k = 1: Mean Accuracy = 89.92%, Best Accuracy = 91.80%, Total Time = 775.52 seconds
# k = 3: Mean Accuracy = 89.96%, Best Accuracy = 93.00%, Total Time = 777.04 seconds
# k = 5: Mean Accuracy = 89.88%, Best Accuracy = 91.80%, Total Time = 750.36 seconds
# k = 7: Mean Accuracy = 89.40%, Best Accuracy = 91.60%, Total Time = 734.64 seconds

# %%
import time
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.neighbors import BallTree
from sklearn.preprocessing import StandardScaler

# Step 1: Fetch and preprocess the MNIST dataset
print("Fetching MNIST dataset...")
X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)
samples=5000
X, y = X[:samples], y[:samples]  # Select first 10,000 images for processing
print(f"Using first {5000} images: {X.shape[0]} training samples.")

X = X / 255.0  # Normalize the pixel values to [0, 1]
y = y.astype(int)  # Convert labels to integers

# Step 2: Standardize the features
print("Standardizing features...")
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Step 3: Define the custom cosine distance function
def cosine_similarity(point1, point2):
    """Calculate the cosine similarity between two points."""
    dot_product = np.dot(point1, point2)
    norm1 = np.linalg.norm(point1)
    norm2 = np.linalg.norm(point2)
    return dot_product / (norm1 * norm2)

def cosine_distance(x, y):
    """Calculate the cosine distance between two vectors."""
    return 1 - cosine_similarity(x, y)

# Step 4: Function to perform k-NN with Ball Tree and k control
def perform_knn_with_ball_tree_k_control(X, y, k_values):
    results = {}
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    
    for k in k_values:
        print(f"\nRunning k-NN with k = {k} using Ball Tree and cosine distance...")
        fold_scores = []
        fold_times = []
        start_time = time.time()
        
        for fold_idx, (train_idx, test_idx) in enumerate(kf.split(X, y), 1):
            print(f"Processing fold {fold_idx} for k = {k}...")
            
            # Split the data for the current fold
            X_train, X_test = X[train_idx], X[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]

            # Build the Ball Tree for the current fold
            ball_tree = BallTree(X_train, metric=cosine_distance)

            # Query the Ball Tree to find the k nearest neighbors
            def knn_with_ball_tree(ball_tree, X_test, k):
                y_pred = []
                for test_point in X_test:
                    dist, ind = ball_tree.query([test_point], k=k)  # Query for k nearest neighbors
                    neighbors_labels = y_train[ind].flatten()  # Get the labels of the neighbors
                    predicted_label = np.bincount(neighbors_labels).argmax()  # Majority vote
                    y_pred.append(predicted_label)
                return np.array(y_pred)

            # Test k-NN with Ball Tree
            y_pred_ball_tree = knn_with_ball_tree(ball_tree, X_test, k=k)

            # Calculate accuracy for this fold
            accuracy = accuracy_score(y_test, y_pred_ball_tree)
            fold_scores.append(accuracy)

            # Track the time taken for this fold
            fold_end_time = time.time()
            fold_time = fold_end_time - start_time
            fold_times.append(fold_time)
            
            print(f"Fold {fold_idx}: Accuracy = {accuracy * 100:.2f}%, Time = {fold_time:.2f} seconds")
        
        # Compute overall results for this value of k
        mean_accuracy = np.mean(fold_scores)
        std_accuracy = np.std(fold_scores)
        total_time = np.sum(fold_times)
        best_accuracy = np.max(fold_scores)

        print(f"\nResults for k = {k}:")
        print(f"Accuracy for each fold: {[f'{score * 100:.2f}%' for score in fold_scores]}")
        print(f"Mean accuracy: {mean_accuracy * 100:.2f}%")
        print(f"Standard deviation of accuracy: {std_accuracy * 100:.2f}%")
        print(f"Best accuracy: {best_accuracy * 100:.2f}%")
        
        # Store results
        results[k] = {
            "mean_accuracy": mean_accuracy,
            "std_accuracy": std_accuracy,
            "total_time": total_time,
            "best_accuracy": best_accuracy,
        }
    
    return results

# Step 5: Run k-NN with multiple values of k
k_values = [1,3,5,7]  # Example k values to test
results = perform_knn_with_ball_tree_k_control(X, y, k_values)

# Step 6: Summarize results
print("\nSummary of results for all k values:")
for k, result in results.items():
    print(f"k = {k}: Mean Accuracy = {result['mean_accuracy'] * 100:.2f}%, Best Accuracy = {result['best_accuracy'] * 100:.2f}%, Total Time = {result['total_time']:.2f} seconds")
# Out:
# Fetching MNIST dataset...
# Using first 5000 images: 5000 training samples.
# Standardizing features...
#
# Running k-NN with k = 1 using Ball Tree and cosine distance...
# Processing fold 1 for k = 1...
# Fold 1: Accuracy = 88.80%, Time = 18.10 seconds
# Processing fold 2 for k = 1...
# Fold 2: Accuracy = 90.40%, Time = 36.89 seconds
# Processing fold 3 for k = 1...
# Fold 3: Accuracy = 90.80%, Time = 55.37 seconds
# Processing fold 4 for k = 1...
# Fold 4: Accuracy = 88.80%, Time = 73.68 seconds
# Processing fold 5 for k = 1...
# Fold 5: Accuracy = 91.80%, Time = 89.18 seconds
# Processing fold 6 for k = 1...
# Fold 6: Accuracy = 90.40%, Time = 104.54 seconds
# Processing fold 7 for k = 1...
# Fold 7: Accuracy = 88.40%, Time = 119.79 seconds
# Processing fold 8 for k = 1...
# Fold 8: Accuracy = 91.20%, Time = 135.05 seconds
# Processing fold 9 for k = 1...
# Fold 9: Accuracy = 89.20%, Time = 150.59 seconds
# Processing fold 10 for k = 1...
# Fold 10: Accuracy = 92.40%, Time = 165.83 seconds
#
# Results for k = 1:
# Accuracy for each fold: ['88.80%', '90.40%', '90.80%', '88.80%', '91.80%', '90.40%', '88.40%', '91.20%', '89.20%', '92.40%']
# Mean accuracy: 90.22%
# Standard deviation of accuracy: 1.30%
# Best accuracy: 92.40%
#
# Running k-NN with k = 3 using Ball Tree and cosine distance...
# Processing fold 1 for k = 3...
# Fold 1: Accuracy = 89.20%, Time = 15.32 seconds
# Processing fold 2 for k = 3...
# Fold 2: Accuracy = 90.80%, Time = 30.49 seconds
# Processing fold 3 for k = 3...
# Fold 3: Accuracy = 90.80%, Time = 45.77 seconds
# Processing fold 4 for k = 3...
# Fold 4: Accuracy = 88.40%, Time = 60.90 seconds
# Processing fold 5 for k = 3...
# Fold 5: Accuracy = 91.40%, Time = 76.09 seconds
# Processing fold 6 for k = 3...
# Fold 6: Accuracy = 89.60%, Time = 91.42 seconds
# Processing fold 7 for k = 3...
# Fold 7: Accuracy = 87.20%, Time = 107.15 seconds
# Processing fold 8 for k = 3...
# Fold 8: Accuracy = 89.60%, Time = 122.39 seconds
# Processing fold 9 for k = 3...
# Fold 9: Accuracy = 89.20%, Time = 137.79 seconds
# Processing fold 10 for k = 3...
# Fold 10: Accuracy = 90.40%, Time = 153.10 seconds
#
# Results for k = 3:
# Accuracy for each fold: ['89.20%', '90.80%', '90.80%', '88.40%', '91.40%', '89.60%', '87.20%', '89.60%', '89.20%', '90.40%']
# Mean accuracy: 89.66%
# Standard deviation of accuracy: 1.19%
# Best accuracy: 91.40%
#
# Running k-NN with k = 5 using Ball Tree and cosine distance...
# Processing fold 1 for k = 5...
# Fold 1: Accuracy = 89.80%, Time = 15.49 seconds
# Processing fold 2 for k = 5...
# Fold 2: Accuracy = 90.60%, Time = 30.82 seconds
# Processing fold 3 for k = 5...
# Fold 3: Accuracy = 91.40%, Time = 46.10 seconds
# Processing fold 4 for k = 5...
# Fold 4: Accuracy = 89.20%, Time = 61.40 seconds
# Processing fold 5 for k = 5...
# Fold 5: Accuracy = 91.20%, Time = 76.72 seconds
# Processing fold 6 for k = 5...
# Fold 6: Accuracy = 88.80%, Time = 92.08 seconds
# Processing fold 7 for k = 5...
# Fold 7: Accuracy = 87.80%, Time = 107.50 seconds
# Processing fold 8 for k = 5...
# Fold 8: Accuracy = 91.00%, Time = 122.85 seconds
# Processing fold 9 for k = 5...
# Fold 9: Accuracy = 89.60%, Time = 138.57 seconds
# Processing fold 10 for k = 5...
# Fold 10: Accuracy = 90.60%, Time = 155.26 seconds
#
# Results for k = 5:
# Accuracy for each fold: ['89.80%', '90.60%', '91.40%', '89.20%', '91.20%', '88.80%', '87.80%', '91.00%', '89.60%', '90.60%']
# Mean accuracy: 90.00%
# Standard deviation of accuracy: 1.11%
# Best accuracy: 91.40%
#
# Running k-NN with k = 7 using Ball Tree and cosine distance...
# Processing fold 1 for k = 7...
# Fold 1: Accuracy = 89.00%, Time = 16.56 seconds
# Processing fold 2 for k = 7...
# Fold 2: Accuracy = 89.80%, Time = 32.96 seconds
# Processing fold 3 for k = 7...
# Fold 3: Accuracy = 90.20%, Time = 49.07 seconds
# Processing fold 4 for k = 7...
# Fold 4: Accuracy = 88.60%, Time = 69.51 seconds
# Processing fold 5 for k = 7...
# Fold 5: Accuracy = 90.20%, Time = 93.88 seconds
# Processing fold 6 for k = 7...
# Fold 6: Accuracy = 89.40%, Time = 119.49 seconds
# Processing fold 7 for k = 7...
# Fold 7: Accuracy = 88.40%, Time = 140.25 seconds
# Processing fold 8 for k = 7...
# Fold 8: Accuracy = 91.60%, Time = 161.03 seconds
# Processing fold 9 for k = 7...
# Fold 9: Accuracy = 89.20%, Time = 188.18 seconds
# Processing fold 10 for k = 7...
# Fold 10: Accuracy = 91.00%, Time = 222.53 seconds
#
# Results for k = 7:
# Accuracy for each fold: ['89.00%', '89.80%', '90.20%', '88.60%', '90.20%', '89.40%', '88.40%', '91.60%', '89.20%', '91.00%']
# Mean accuracy: 89.74%
# Standard deviation of accuracy: 0.98%
# Best accuracy: 91.60%
#
# Summary of results for all k values:
# k = 1: Mean Accuracy = 90.22%, Best Accuracy = 92.40%, Total Time = 949.00 seconds
# k = 3: Mean Accuracy = 89.66%, Best Accuracy = 91.40%, Total Time = 840.41 seconds
# k = 5: Mean Accuracy = 90.00%, Best Accuracy = 91.40%, Total Time = 846.78 seconds
# k = 7: Mean Accuracy = 89.74%, Best Accuracy = 91.60%, Total Time = 1093.46 seconds

# %%
import time
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# Step 1: Fetch and preprocess the MNIST dataset
print("Fetching MNIST dataset...")
X, y = fetch_openml('mnist_784', version=1, return_X_y=True, as_frame=False)
samples=5000
X, y = X[:samples], y[:samples]  # Select first 10,000 images for processing
print(f"Using first {samples} images: {X.shape[0]} training samples.")

X = X / 255.0  # Normalize pixel values to [0, 1]
y = y.astype(int)  # Convert labels to integers

# Step 2: Standardize the features
print("Standardizing features...")
scaler = StandardScaler()
X = scaler.fit_transform(X)

# Step 3: Manhattan Distance function
def manhattan_distance(x, y):
    """Calculate the Manhattan (L1) distance between two points."""
    return np.sum(np.abs(x - y))

# Step 4: Implement k-NN without BallTree
def knn_predict(X_train, y_train, X_test, k=3):
    """Predict labels using k-NN and Manhattan distance."""
    y_pred = []
    
    # For each test point, calculate distances to all training points
    for test_point in X_test:
        distances = [manhattan_distance(test_point, train_point) for train_point in X_train]
        
        # Get indices of the k smallest distances
        k_indices = np.argsort(distances)[:k]
        k_nearest_labels = y_train[k_indices]
        
        # Majority vote
        predicted_label = np.bincount(k_nearest_labels).argmax()
        y_pred.append(predicted_label)
    
    return np.array(y_pred)

# Step 5: Function to perform k-NN with k control
def perform_knn_with_k_control(X, y, k_values):
    results = {}
    kf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    
    for k in k_values:
        print(f"\nRunning k-NN with k = {k} using Manhattan distance...")
        fold_scores = []
        fold_times = []
        start_time = time.time()
        
        for fold_idx, (train_idx, test_idx) in enumerate(kf.split(X, y), 1):
            print(f"Processing fold {fold_idx} for k = {k}...")
            
            # Split the data for the current fold
            X_train, X_test = X[train_idx], X[test_idx]
            y_train, y_test = y[train_idx], y[test_idx]

            # Predict using k-NN
            print(f"Predicting using k-NN for fold {fold_idx}...")
            y_pred = knn_predict(X_train, y_train, X_test, k=k)

            # Calculate accuracy for this fold
            accuracy = accuracy_score(y_test, y_pred)
            fold_scores.append(accuracy)

            # Track the time taken for this fold
            fold_end_time = time.time()
            fold_time = fold_end_time - start_time
            fold_times.append(fold_time)
            
            print(f"Fold {fold_idx}: Accuracy = {accuracy * 100:.2f}%, Time = {fold_time:.2f} seconds")
        
        # Compute overall results for this value of k
        mean_accuracy = np.mean(fold_scores)
        std_accuracy = np.std(fold_scores)
        total_time = np.sum(fold_times)
        best_accuracy = np.max(fold_scores)

        print(f"\nResults for k = {k}:")
        print(f"Accuracy for each fold: {[f'{score * 100:.2f}%' for score in fold_scores]}")
        print(f"Mean accuracy: {mean_accuracy * 100:.2f}%")
        print(f"Standard deviation of accuracy: {std_accuracy * 100:.2f}%")
        print(f"Best accuracy: {best_accuracy * 100:.2f}%")
        
        # Store results
        results[k] = {
            "mean_accuracy": mean_accuracy,
            "std_accuracy": std_accuracy,
            "total_time": total_time,
            "best_accuracy": best_accuracy,
        }
    
    return results

# Step 6: Run k-NN with multiple values of k
k_values = [1,3,5,7]  # Example k values to test
results = perform_knn_with_k_control(X, y, k_values)

# Step 7: Summarize results
print("\nSummary of results for all k values:")
for k, result in results.items():
    print(f"k = {k}: Mean Accuracy = {result['mean_accuracy'] * 100:.2f}%, Best Accuracy = {result['best_accuracy'] * 100:.2f}%, Total Time = {result['total_time']:.2f} seconds")
# Out:
# Fetching MNIST dataset...
# Using first 5000 images: 5000 training samples.
# Standardizing features...
#
# Running k-NN with k = 1 using Manhattan distance...
# Processing fold 1 for k = 1...
# Predicting using k-NN for fold 1...
# Fold 1: Accuracy = 91.80%, Time = 26.03 seconds
# Processing fold 2 for k = 1...
# Predicting using k-NN for fold 2...
# Fold 2: Accuracy = 89.40%, Time = 54.92 seconds
# Processing fold 3 for k = 1...
# Predicting using k-NN for fold 3...
# Fold 3: Accuracy = 93.20%, Time = 86.63 seconds
# Processing fold 4 for k = 1...
# Predicting using k-NN for fold 4...
# Fold 4: Accuracy = 91.40%, Time = 121.50 seconds
# Processing fold 5 for k = 1...
# Predicting using k-NN for fold 5...
# Fold 5: Accuracy = 92.00%, Time = 153.72 seconds
# Processing fold 6 for k = 1...
# Predicting using k-NN for fold 6...
# Fold 6: Accuracy = 91.20%, Time = 188.90 seconds
# Processing fold 7 for k = 1...
# Predicting using k-NN for fold 7...
# Fold 7: Accuracy = 93.40%, Time = 219.91 seconds
# Processing fold 8 for k = 1...
# Predicting using k-NN for fold 8...
# Fold 8: Accuracy = 93.20%, Time = 249.15 seconds
# Processing fold 9 for k = 1...
# Predicting using k-NN for fold 9...
# Fold 9: Accuracy = 90.60%, Time = 278.74 seconds
# Processing fold 10 for k = 1...
# Predicting using k-NN for fold 10...
# Fold 10: Accuracy = 93.00%, Time = 313.21 seconds
#
# Results for k = 1:
# Accuracy for each fold: ['91.80%', '89.40%', '93.20%', '91.40%', '92.00%', '91.20%', '93.40%', '93.20%', '90.60%', '93.00%']
# Mean accuracy: 91.92%
# Standard deviation of accuracy: 1.25%
# Best accuracy: 93.40%
#
# Running k-NN with k = 3 using Manhattan distance...
# Processing fold 1 for k = 3...
# Predicting using k-NN for fold 1...
# Fold 1: Accuracy = 90.60%, Time = 32.73 seconds
# Processing fold 2 for k = 3...
# Predicting using k-NN for fold 2...
# Fold 2: Accuracy = 91.60%, Time = 61.53 seconds
# Processing fold 3 for k = 3...
# Predicting using k-NN for fold 3...
# Fold 3: Accuracy = 92.20%, Time = 90.48 seconds
# Processing fold 4 for k = 3...
# Predicting using k-NN for fold 4...
# Fold 4: Accuracy = 92.80%, Time = 119.62 seconds
# Processing fold 5 for k = 3...
# Predicting using k-NN for fold 5...
# Fold 5: Accuracy = 90.40%, Time = 151.93 seconds
# Processing fold 6 for k = 3...
# Predicting using k-NN for fold 6...
# Fold 6: Accuracy = 90.20%, Time = 182.66 seconds
# Processing fold 7 for k = 3...
# Predicting using k-NN for fold 7...
# Fold 7: Accuracy = 92.40%, Time = 216.77 seconds
# Processing fold 8 for k = 3...
# Predicting using k-NN for fold 8...
# Fold 8: Accuracy = 94.20%, Time = 250.14 seconds
# Processing fold 9 for k = 3...
# Predicting using k-NN for fold 9...
# Fold 9: Accuracy = 90.60%, Time = 282.29 seconds
# Processing fold 10 for k = 3...
# Predicting using k-NN for fold 10...
# Fold 10: Accuracy = 92.60%, Time = 314.79 seconds
#
# Results for k = 3:
# Accuracy for each fold: ['90.60%', '91.60%', '92.20%', '92.80%', '90.40%', '90.20%', '92.40%', '94.20%', '90.60%', '92.60%']
# Mean accuracy: 91.76%
# Standard deviation of accuracy: 1.24%
# Best accuracy: 94.20%
#
# Running k-NN with k = 5 using Manhattan distance...
# Processing fold 1 for k = 5...
# Predicting using k-NN for fold 1...
# Fold 1: Accuracy = 90.80%, Time = 34.86 seconds
# Processing fold 2 for k = 5...
# Predicting using k-NN for fold 2...
# Fold 2: Accuracy = 90.60%, Time = 64.34 seconds
# Processing fold 3 for k = 5...
# Predicting using k-NN for fold 3...
# Fold 3: Accuracy = 93.80%, Time = 95.16 seconds
# Processing fold 4 for k = 5...
# Predicting using k-NN for fold 4...
# Fold 4: Accuracy = 92.00%, Time = 126.27 seconds
# Processing fold 5 for k = 5...
# Predicting using k-NN for fold 5...
# Fold 5: Accuracy = 90.40%, Time = 161.40 seconds
# Processing fold 6 for k = 5...
# Predicting using k-NN for fold 6...
# Fold 6: Accuracy = 89.20%, Time = 197.07 seconds
# Processing fold 7 for k = 5...
# Predicting using k-NN for fold 7...
# Fold 7: Accuracy = 91.60%, Time = 229.95 seconds
# Processing fold 8 for k = 5...
# Predicting using k-NN for fold 8...
# Fold 8: Accuracy = 94.80%, Time = 261.64 seconds
# Processing fold 9 for k = 5...
# Predicting using k-NN for fold 9...
# Fold 9: Accuracy = 90.60%, Time = 293.21 seconds
# Processing fold 10 for k = 5...
# Predicting using k-NN for fold 10...
# Fold 10: Accuracy = 92.20%, Time = 325.24 seconds
#
# Results for k = 5:
# Accuracy for each fold: ['90.80%', '90.60%', '93.80%', '92.00%', '90.40%', '89.20%', '91.60%', '94.80%', '90.60%', '92.20%']
# Mean accuracy: 91.60%
# Standard deviation of accuracy: 1.59%
# Best accuracy: 94.80%
#
# Running k-NN with k = 7 using Manhattan distance...
# Processing fold 1 for k = 7...
# Predicting using k-NN for fold 1...
# Fold 1: Accuracy = 90.00%, Time = 30.77 seconds
# Processing fold 2 for k = 7...
# Predicting using k-NN for fold 2...
# Fold 2: Accuracy = 90.00%, Time = 57.45 seconds
# Processing fold 3 for k = 7...
# Predicting using k-NN for fold 3...
# Fold 3: Accuracy = 94.40%, Time = 85.75 seconds
# Processing fold 4 for k = 7...
# Predicting using k-NN for fold 4...
# Fold 4: Accuracy = 91.60%, Time = 116.76 seconds
# Processing fold 5 for k = 7...
# Predicting using k-NN for fold 5...
# Fold 5: Accuracy = 89.40%, Time = 149.70 seconds
# Processing fold 6 for k = 7...
# Predicting using k-NN for fold 6...
# Fold 6: Accuracy = 89.80%, Time = 178.96 seconds
# Processing fold 7 for k = 7...
# Predicting using k-NN for fold 7...
# Fold 7: Accuracy = 91.40%, Time = 213.15 seconds
# Processing fold 8 for k = 7...
# Predicting using k-NN for fold 8...
# Fold 8: Accuracy = 94.20%, Time = 248.07 seconds
# Processing fold 9 for k = 7...
# Predicting using k-NN for fold 9...
# Fold 9: Accuracy = 91.20%, Time = 279.26 seconds
# Processing fold 10 for k = 7...
# Predicting using k-NN for fold 10...
# Fold 10: Accuracy = 92.80%, Time = 308.90 seconds
#
# Results for k = 7:
# Accuracy for each fold: ['90.00%', '90.00%', '94.40%', '91.60%', '89.40%', '89.80%', '91.40%', '94.20%', '91.20%', '92.80%']
# Mean accuracy: 91.48%
# Standard deviation of accuracy: 1.71%
# Best accuracy: 94.40%
#
# Summary of results for all k values:
# k = 1: Mean Accuracy = 91.92%, Best Accuracy = 93.40%, Total Time = 1692.71 seconds
# k = 3: Mean Accuracy = 91.76%, Best Accuracy = 94.20%, Total Time = 1702.94 seconds
# k = 5: Mean Accuracy = 91.60%, Best Accuracy = 94.80%, Total Time = 1789.13 seconds
# k = 7: Mean Accuracy = 91.48%, Best Accuracy = 94.40%, Total Time = 1668.77 seconds
